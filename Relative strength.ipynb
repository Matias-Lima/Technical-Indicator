# %%
import pandas as pd
import pandas_ta as ta
import yfinance as yf
import matplotlib.pyplot as plt
plt.style.use('default')

start_date = "2019-10-27"
end_date = "2022-08-02"
stock1 = "AAPL"
df = yf.download([stock1], start = start_date, end = end_date)
#print('data fields downloaded:', set(df.columns.get_level_values(0)))

#---------------- RELATIVE STRENGTH --------------------
# The Relative Strength Index

df['RSI'] = ta.rsi(df['Close'],20)
df[['Close','RSI']].plot(figsize=(12,12))
plt.show()

# William's Percent R is a momentum oscillator similar to the RSI that attempts to identify overbought and oversold conditions.
"""df['William s'] = ta.willr(df['High'],df['Low'], df['Close'])
print(df['William s'])
df[['William s']].plot(figsize=(12,12))
plt.show()"""
#--------------------------------------------
# Out:
# [*********************100%***********************]  1 of 1 completed
# "df['William s'] = ta.willr(df['High'],df['Low'], df['Close'])\nprint(df['William s'])\ndf[['William s']].plot(figsize=(12,12))\nplt.show()"
